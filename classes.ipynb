# %%
import pandas as pd
from typing import List
import string

# %%
class Trader:
    
    def bid(self):
        return None

    def run(self, state):
        print("traderData: " + state.traderData)


    print(run())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 class Trader:
#       3     def bid(self):
#       4         return None
#
# Cell In[4], line 10, in Trader()
#       6 def run(self, state):
#       7     print("traderData: " + state.traderData)
# ---> 10 print(run())
#
# TypeError: Trader.run() missing 2 required positional arguments: 'self' and 'state'
